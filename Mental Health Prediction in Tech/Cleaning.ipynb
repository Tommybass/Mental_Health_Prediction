# %% [markdown]
# ## Machine Learning for diagnosing and predicting Mental Health in Tech Community
#
# This project is aimed to predict mental health using machine learning,
#
# Mental illness is one of the largest burden of disease in the UK. Severe mental disorders effect employees` work performance, students` academic performance and overall quality of life. Mental illnesses are more common, long-lasting and impactful than other health conditions. Not only impacts on individuals but also society. Mental ill health is responsible for 72 million working days lost and costs £34.9 billion each year (Mental Health First Aid England). Patients may avoid mental illness consequences by being provided with proper treatment after being diagnosed.
#
# Digital healthcare technologies, e.g. Artificial Intelligence (AI) and Machine Learning(ML), has been growing interests in the application of the approach to address diagnostic and prediction issues in mental healthcare. Can we actually diagnose mental conditions properly with the aid of AI and ML? After the diagnoses, can the AI and ML systems tell how severe the condition is, and what might be the consequences? We might also consider the AI and ML treatment recommendations.
#
# The aim of the project is to use AI and ML to support diagnosis, prediction and treatment of mental health disorders, particularly for people in tech community.   The specific objectives of the work can be summarized as:
#
# • To develop AI and ML systems to diagnose mental health disorders
#
# • To investigate AI and ML systems to predict consequences of a mental health disorder
#
#
#
# -----------------------------------------------------------
# # Content of Dataset
#
#
#  0   ResponseID           -Drop
#  1   Are you selfemployed
#  2   How many employees does your company or organization have
#  3   Is your employer primarily a tech companyorganization
#  4   Is your primary role within your company related to techIT
#  5   Do you have previous employers
#  6   Do you have a family history of mental illness
#  7   Have you had a mental health disorder in the past
#  8   Do you currently have a mental health disorder
#  9   If yes, what conditions have you been diagnosed with   (Target Value 2) "This should not be part of the input features"
#  10  If maybe, what conditions do you believe you have
#  11  Have you been diagnosed with a mental health condition by a medical professional (Rename and change to numerical value) -Target Value
#  12  If so, what conditions were you diagnosed with
#  13  Have you ever sought treatment for a mental health issue from a mental health professional
#  14  What is your age    - Rename
#  15  What is your gender - Rename
#  16  Age Group           - Rename
#  17  What country do you live in         - ( Compare countries)
#  18  What US state or territory do you live in
#  19  What country do you work in         - (Compare these using HeatMap)
#  20  What US state or territory do you work in
#  21  Which of the following best describes your work position
#  22  Do you work remotely
#  23  Question Group      - Drop
#  24  Questions about speaking openly about mental health vs physical health
#  25  Question            -  Drop
#  26  Response            -  Drop
#
#
# ### 2 Things, check the main target first. Then if yes, then what condition have they been dignosed with.

# %%
#import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


from scipy import stats
from scipy.stats import randint

#PreProcessing 
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.datasets import make_classification
from sklearn.preprocessing import binarize, LabelEncoder, MinMaxScaler


# models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# Validation libraries
from sklearn import metrics
from sklearn.metrics import accuracy_score, mean_squared_error, precision_recall_curve
from sklearn.model_selection import cross_val_score

# %%
#loading dataset
filename = 'data/Survey_Data.csv'
df = pd.read_csv(filename)

# %%
# display thge first 5 rows in the dataset
df.head(5)
# Out:
#   ResponseID  Are you selfemployed  \
# 0     r00000                 False
# 1     r00000                 False
# 2     r00000                 False
# 3     r00000                 False
# 4     r00000                 False
#
#   How many employees does your company or organization have  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                             26-100
# 4                                             26-100
#
#   Is your employer primarily a tech companyorganization  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to techIT  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Do you have previous employers  \
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
#
#   Do you have a family history of mental illness  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
#
#   Have you had a mental health disorder in the past  \
# 0                                               Yes
# 1                                               Yes
# 2                                               Yes
# 3                                               Yes
# 4                                               Yes
#
#   Do you currently have a mental health disorder  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
#
#   If yes, what conditions have you been diagnosed with  ...  \
# 0                                                NaN    ...
# 1                                                NaN    ...
# 2                                                NaN    ...
# 3                                                NaN    ...
# 4                                                NaN    ...
#
#   What country do you live in  What US state or territory do you live in  \
# 0              United Kingdom                                        NaN
# 1              United Kingdom                                        NaN
# 2              United Kingdom                                        NaN
# 3              United Kingdom                                        NaN
# 4              United Kingdom                                        NaN
#
#   What country do you work in  What US state or territory do you work in  \
# 0              United Kingdom                                        NaN
# 1              United Kingdom                                        NaN
# 2              United Kingdom                                        NaN
# 3              United Kingdom                                        NaN
# 4              United Kingdom                                        NaN
#
#    Which of the following best describes your work position  \
# 0                                 Back-end Developer
# 1                                 Back-end Developer
# 2                                 Back-end Developer
# 3                                 Back-end Developer
# 4                                 Back-end Developer
#
#   Do you work remotely                                     Question Group  \
# 0            Sometimes  Resources for employees with mental health dis...
# 1            Sometimes  Resources for employees with mental health dis...
# 2            Sometimes  Safe and supportive workplce for those with me...
# 3            Sometimes  Resources for employees with mental health dis...
# 4            Sometimes  Resources for employees with mental health dis...
#
#   Question about speaking openly about mental health vs physical health  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#                                             Question  \
# 0  Does your employer provide mental health benef...
# 1  Do you know the options for mental health care...
# 2  Has your employer ever formally discussed ment...
# 3  Does your employer offer resources to learn mo...
# 4  Is your anonymity protected if you choose to t...
#
#                           Response
# 0  Not eligible for coverage / N/A
# 1                              NaN
# 2                               No
# 3                               No
# 4                     I don't know
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60186 entries, 0 to 60185
# Data columns (total 27 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   ResponseID                                                                                  60186 non-null  object
#  1   Are you selfemployed                                                                        60186 non-null  bool
#  2   How many employees does your company or organization have                                   48132 non-null  object
#  3   Is your employer primarily a tech companyorganization                                       48132 non-null  object
#  4   Is your primary role within your company related to techIT                                  11046 non-null  object
#  5   Do you have previous employers                                                              60186 non-null  bool
#  6   Do you have a family history of mental illness                                              60186 non-null  object
#  7   Have you had a mental health disorder in the past                                           60186 non-null  object
#  8   Do you currently have a mental health disorder                                              60186 non-null  object
#  9   If yes, what conditions have you been diagnosed with                                        23856 non-null  object
#  10  If maybe, what conditions do you believe you have                                           13524 non-null  object
#  11  Have you been diagnosed with a mental health condition by a medical professional            60186 non-null  bool
#  12  If so, what conditions were you diagnosed with                                              29862 non-null  object
#  13  Have you ever sought treatment for a mental health issue from a mental health professional  60186 non-null  bool
#  14  What is your age                                                                            60102 non-null  float64
#  15  What is your gender                                                                         60186 non-null  object
#  16  Age Group                                                                                   60186 non-null  object
#  17  What country do you live in                                                                 60186 non-null  object
#  18  What US state or territory do you live in                                                   35280 non-null  object
#  19  What country do you work in                                                                 60186 non-null  object
#  20  What US state or territory do you work in                                                   35742 non-null  object
#  21  Which of the following best describes your work position                                    60186 non-null  object
#  22  Do you work remotely                                                                        60186 non-null  object
#  23  Question Group                                                                              51588 non-null  object
#  24  Question about speaking openly about mental health vs physical health                       60186 non-null  object
#  25  Question                                                                                    60186 non-null  object
#  26  Response                                                                                    43846 non-null  object
# dtypes: bool(4), float64(1), object(22)
# memory usage: 10.8+ MB

# %%
#types of data in the Dataframe 
df.dtypes
# Out:
# ResponseID                                                                                     object
# Are you selfemployed                                                                             bool
# How many employees does your company or organization have                                      object
# Is your employer primarily a tech companyorganization                                          object
# Is your primary role within your company related to techIT                                     object
# Do you have previous employers                                                                   bool
# Do you have a family history of mental illness                                                 object
# Have you had a mental health disorder in the past                                              object
# Do you currently have a mental health disorder                                                 object
# If yes, what conditions have you been diagnosed with                                           object
# If maybe, what conditions do you believe you have                                              object
# Have you been diagnosed with a mental health condition by a medical professional                 bool
# If so, what conditions were you diagnosed with                                                 object
# Have you ever sought treatment for a mental health issue from a mental health professional       bool
# What is your age                                                                              float64
# What is your gender                                                                            object
# Age Group                                                                                      object
# What country do you live in                                                                    object
# What US state or territory do you live in                                                      object
# What country do you work in                                                                    object
# What US state or territory do you work in                                                      object
# Which of the following best describes your work position                                       object
# Do you work remotely                                                                           object
# Question Group                                                                                 object
# Question about speaking openly about mental health vs physical health                          object
# Question                                                                                       object
# Response                                                                                       object
# dtype: object

# %%
print(" VALUES IN DATASET ")
#count the values in the data for each column
df.count()
# Out:
#  VALUES IN DATASET
# ResponseID                                                                                    60186
# Are you selfemployed                                                                          60186
# How many employees does your company or organization have                                     48132
# Is your employer primarily a tech companyorganization                                         48132
# Is your primary role within your company related to techIT                                    11046
# Do you have previous employers                                                                60186
# Do you have a family history of mental illness                                                60186
# Have you had a mental health disorder in the past                                             60186
# Do you currently have a mental health disorder                                                60186
# If yes, what conditions have you been diagnosed with                                          23856
# If maybe, what conditions do you believe you have                                             13524
# Have you been diagnosed with a mental health condition by a medical professional              60186
# If so, what conditions were you diagnosed with                                                29862
# Have you ever sought treatment for a mental health issue from a mental health professional    60186
# What is your age                                                                              60102
# What is your gender                                                                           60186
# Age Group                                                                                     60186
# What country do you live in                                                                   60186
# What US state or territory do you live in                                                     35280
# What country do you work in                                                                   60186
# What US state or territory do you work in                                                     35742
# Which of the following best describes your work position                                      60186
# Do you work remotely                                                                          60186
# Question Group                                                                                51588
# Question about speaking openly about mental health vs physical health                         60186
# Question                                                                                      60186
# Response                                                                                      43846
# dtype: int64

# %% [markdown]
# As seen in the data, there are about 22 object tpyes, 4 boolean values and just one float

# %% [markdown]
# # Data Cleaning

# %%
#rename dataset
df_clean = df

# %%
#check null values
df_clean.isnull()
# Out:
#        ResponseID  Are you selfemployed  \
# 0           False                 False
# 1           False                 False
# 2           False                 False
# 3           False                 False
# 4           False                 False
# ...           ...                   ...
# 60181       False                 False
# 60182       False                 False
# 60183       False                 False
# 60184       False                 False
# 60185       False                 False
#
#        How many employees does your company or organization have  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 60181                                              False
# 60182                                              False
# 60183                                              False
# 60184                                              False
# 60185                                              False
#
#        Is your employer primarily a tech companyorganization  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 60181                                              False
# 60182                                              False
# 60183                                              False
# 60184                                              False
# 60185                                              False
#
#        Is your primary role within your company related to techIT  \
# 0                                                   True
# 1                                                   True
# 2                                                   True
# 3                                                   True
# 4                                                   True
# ...                                                  ...
# 60181                                               True
# 60182                                               True
# 60183                                               True
# 60184                                               True
# 60185                                               True
#
#        Do you have previous employers  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ...                               ...
# 60181                           False
# 60182                           False
# 60183                           False
# 60184                           False
# 60185                           False
#
#        Do you have a family history of mental illness  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 60181                                           False
# 60182                                           False
# 60183                                           False
# 60184                                           False
# 60185                                           False
#
#        Have you had a mental health disorder in the past  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 60181                                              False
# 60182                                              False
# 60183                                              False
# 60184                                              False
# 60185                                              False
#
#        Do you currently have a mental health disorder  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 60181                                           False
# 60182                                           False
# 60183                                           False
# 60184                                           False
# 60185                                           False
#
#        If yes, what conditions have you been diagnosed with  ...  \
# 0                                                   True     ...
# 1                                                   True     ...
# 2                                                   True     ...
# 3                                                   True     ...
# 4                                                   True     ...
# ...                                                  ...     ...
# 60181                                              False     ...
# 60182                                              False     ...
# 60183                                              False     ...
# 60184                                              False     ...
# 60185                                              False     ...
#
#        What country do you live in  What US state or territory do you live in  \
# 0                            False                                       True
# 1                            False                                       True
# 2                            False                                       True
# 3                            False                                       True
# 4                            False                                       True
# ...                            ...                                        ...
# 60181                        False                                       True
# 60182                        False                                       True
# 60183                        False                                       True
# 60184                        False                                       True
# 60185                        False                                       True
#
#        What country do you work in  What US state or territory do you work in  \
# 0                            False                                       True
# 1                            False                                       True
# 2                            False                                       True
# 3                            False                                       True
# 4                            False                                       True
# ...                            ...                                        ...
# 60181                        False                                       True
# 60182                        False                                       True
# 60183                        False                                       True
# 60184                        False                                       True
# 60185                        False                                       True
#
#        Which of the following best describes your work position  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 60181                                              False
# 60182                                              False
# 60183                                              False
# 60184                                              False
# 60185                                              False
#
#        Do you work remotely  Question Group  \
# 0                     False           False
# 1                     False           False
# 2                     False           False
# 3                     False           False
# 4                     False           False
# ...                     ...             ...
# 60181                 False           False
# 60182                 False           False
# 60183                 False           False
# 60184                 False           False
# 60185                 False           False
#
#        Question about speaking openly about mental health vs physical health  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 60181                                              False
# 60182                                              False
# 60183                                              False
# 60184                                              False
# 60185                                              False
#
#        Question  Response
# 0         False     False
# 1         False      True
# 2         False     False
# 3         False     False
# 4         False     False
# ...         ...       ...
# 60181     False     False
# 60182     False     False
# 60183     False     False
# 60184     False     False
# 60185     False     False
#
# [60186 rows x 27 columns]

# %%
if df_clean.isnull().sum().sum() == 0:
    print('You have no missing data in the dataset.')
else:
    print('There are {} missing data in your dataset.'.format(df_clean.isnull().sum().sum()))
# Out:
# There are 260936 missing data in your dataset.

# %%
#check the missing data in the columns and their unique values

# %%
#giving values for the different data types
String = 'Nan'
Float = 0.0
# creating a according to data type
IntFeatures = ['What is your age ']
stringFeatures = ['']

# %%
#drop columns 
to_drop = ['ResponseID','Question Group','Question','Response']
df_clean.drop(to_drop,inplace=True, axis=1)

# %% [markdown]
# Dropped all these Columns
#
# * ResponseID - This column is unique identifiers that do not contibrute to the modeling or analysis of the aims of the project
# * Question Group - There is no need to have this in the data as it has no relevance for the prediction
# * Response - This was dropped to reduce the

# %%
#Display 
df_clean.head(5)
# Out:
#    Are you selfemployed  \
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
#   How many employees does your company or organization have  \
# 0                                             26-100
# 1                                             26-100
# 2                                             26-100
# 3                                             26-100
# 4                                             26-100
#
#   Is your employer primarily a tech companyorganization  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Is your primary role within your company related to techIT  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Do you have previous employers  \
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
#
#   Do you have a family history of mental illness  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
#
#   Have you had a mental health disorder in the past  \
# 0                                               Yes
# 1                                               Yes
# 2                                               Yes
# 3                                               Yes
# 4                                               Yes
#
#   Do you currently have a mental health disorder  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
#
#   If yes, what conditions have you been diagnosed with  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   If maybe, what conditions do you believe you have  ...  What is your age  \
# 0                                               NaN  ...              39.0
# 1                                               NaN  ...              39.0
# 2                                               NaN  ...              39.0
# 3                                               NaN  ...              39.0
# 4                                               NaN  ...              39.0
#
#   What is your gender   Age Group  What country do you live in  \
# 0                 Male      36-40               United Kingdom
# 1                 Male      36-40               United Kingdom
# 2                 Male      36-40               United Kingdom
# 3                 Male      36-40               United Kingdom
# 4                 Male      36-40               United Kingdom
#
#   What US state or territory do you live in What country do you work in  \
# 0                                       NaN              United Kingdom
# 1                                       NaN              United Kingdom
# 2                                       NaN              United Kingdom
# 3                                       NaN              United Kingdom
# 4                                       NaN              United Kingdom
#
#   What US state or territory do you work in  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Which of the following best describes your work position  \
# 0                                 Back-end Developer
# 1                                 Back-end Developer
# 2                                 Back-end Developer
# 3                                 Back-end Developer
# 4                                 Back-end Developer
#
#   Do you work remotely  \
# 0            Sometimes
# 1            Sometimes
# 2            Sometimes
# 3            Sometimes
# 4            Sometimes
#
#   Question about speaking openly about mental health vs physical health
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# [5 rows x 23 columns]

# %%
#Findig out the gender types included in the forms 
#rename column 

gender = df_clean['What is your gender '].unique()
print(gender)
# Out:
# ['Male' 'Female' 'Trans/Other']

# %% [markdown]
# ## Renaming Columns

# %%
#Rename columns 
df_clean.rename(
    columns={"What is your age": "Age", "What is your gender": "Gender", "Age Group": "Age group" ,"Is your employer primarily a tech companyorganization":
            "Tech Company","How many employees does your company or organization have":"Number of employees"},
    inplace=True,
)

df_clean

#Look at the data and change the column Age,
#Do you have previous employmet,
#do you currently have a mental health disorder
#What is your Age
#Do you have a family history of mental illness
#If yes, what conditions have you been diagnosed with
#What country do you live in
#What US state or territory do you live in
#Which of the following best describes your work position
# Out:
#        Are you selfemployed Number of employees Tech Company  \
# 0                     False              26-100         True
# 1                     False              26-100         True
# 2                     False              26-100         True
# 3                     False              26-100         True
# 4                     False              26-100         True
# ...                     ...                 ...          ...
# 60181                 False             100-500         True
# 60182                 False             100-500         True
# 60183                 False             100-500         True
# 60184                 False             100-500         True
# 60185                 False             100-500         True
#
#       Is your primary role within your company related to techIT  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60181                                                NaN
# 60182                                                NaN
# 60183                                                NaN
# 60184                                                NaN
# 60185                                                NaN
#
#        Do you have previous employers  \
# 0                                True
# 1                                True
# 2                                True
# 3                                True
# 4                                True
# ...                               ...
# 60181                           False
# 60182                           False
# 60183                           False
# 60184                           False
# 60185                           False
#
#       Do you have a family history of mental illness  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
# ...                                              ...
# 60181                                   I don't know
# 60182                                   I don't know
# 60183                                   I don't know
# 60184                                   I don't know
# 60185                                   I don't know
#
#       Have you had a mental health disorder in the past  \
# 0                                                   Yes
# 1                                                   Yes
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 60181                                               Yes
# 60182                                               Yes
# 60183                                               Yes
# 60184                                               Yes
# 60185                                               Yes
#
#       Do you currently have a mental health disorder  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
# ...                                              ...
# 60181                                            Yes
# 60182                                            Yes
# 60183                                            Yes
# 60184                                            Yes
# 60185                                            Yes
#
#       If yes, what conditions have you been diagnosed with  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60181  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60182  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60183  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60184  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60185  Obsessive-Compulsive Disorder|Eating Disorder ...
#
#       If maybe, what conditions do you believe you have  ...   Age  \
# 0                                                   NaN  ...  39.0
# 1                                                   NaN  ...  39.0
# 2                                                   NaN  ...  39.0
# 3                                                   NaN  ...  39.0
# 4                                                   NaN  ...  39.0
# ...                                                 ...  ...   ...
# 60181                                               NaN  ...  25.0
# 60182                                               NaN  ...  25.0
# 60183                                               NaN  ...  25.0
# 60184                                               NaN  ...  25.0
# 60185                                               NaN  ...  25.0
#
#       What is your gender   Age group  What country do you live in  \
# 0                     Male      36-40               United Kingdom
# 1                     Male      36-40               United Kingdom
# 2                     Male      36-40               United Kingdom
# 3                     Male      36-40               United Kingdom
# 4                     Male      36-40               United Kingdom
# ...                    ...        ...                          ...
# 60181          Trans/Other      20-25                       Canada
# 60182          Trans/Other      20-25                       Canada
# 60183          Trans/Other      20-25                       Canada
# 60184          Trans/Other      20-25                       Canada
# 60185          Trans/Other      20-25                       Canada
#
#       What US state or territory do you live in What country do you work in  \
# 0                                           NaN              United Kingdom
# 1                                           NaN              United Kingdom
# 2                                           NaN              United Kingdom
# 3                                           NaN              United Kingdom
# 4                                           NaN              United Kingdom
# ...                                         ...                         ...
# 60181                                       NaN                      Canada
# 60182                                       NaN                      Canada
# 60183                                       NaN                      Canada
# 60184                                       NaN                      Canada
# 60185                                       NaN                      Canada
#
#       What US state or territory do you work in  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 60181                                       NaN
# 60182                                       NaN
# 60183                                       NaN
# 60184                                       NaN
# 60185                                       NaN
#
#       Which of the following best describes your work position  \
# 0                                     Back-end Developer
# 1                                     Back-end Developer
# 2                                     Back-end Developer
# 3                                     Back-end Developer
# 4                                     Back-end Developer
# ...                                                  ...
# 60181                                              Other
# 60182                                              Other
# 60183                                              Other
# 60184                                              Other
# 60185                                              Other
#
#       Do you work remotely  \
# 0                Sometimes
# 1                Sometimes
# 2                Sometimes
# 3                Sometimes
# 4                Sometimes
# ...                    ...
# 60181            Sometimes
# 60182            Sometimes
# 60183            Sometimes
# 60184            Sometimes
# 60185            Sometimes
#
#       Question about speaking openly about mental health vs physical health
# 0                                                     No
# 1                                                     No
# 2                                                     No
# 3                                                     No
# 4                                                     No
# ...                                                  ...
# 60181                                                 No
# 60182                                                 No
# 60183                                                 No
# 60184                                                 No
# 60185                                                 No
#
# [60186 rows x 23 columns]

# %%
df_clean['Question about speaking openly about mental health vs physical health'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#Rename columns 
df_clean.rename(
    columns={"What is your age": "Age", "What is your gender": "Gender", "Age Group": "Age group" ,"Is your employer primarily a tech companyorganization":
            "Tech Company","How many employees does your company or organization have":"Number of employees"},
    inplace=True,
)

df_clean
# Out:
#        Are you selfemployed Number of employees Tech Company  \
# 0                     False              26-100         True
# 1                     False              26-100         True
# 2                     False              26-100         True
# 3                     False              26-100         True
# 4                     False              26-100         True
# ...                     ...                 ...          ...
# 60181                 False             100-500         True
# 60182                 False             100-500         True
# 60183                 False             100-500         True
# 60184                 False             100-500         True
# 60185                 False             100-500         True
#
#       Is your primary role within your company related to techIT  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60181                                                NaN
# 60182                                                NaN
# 60183                                                NaN
# 60184                                                NaN
# 60185                                                NaN
#
#        Do you have previous employers  \
# 0                                True
# 1                                True
# 2                                True
# 3                                True
# 4                                True
# ...                               ...
# 60181                           False
# 60182                           False
# 60183                           False
# 60184                           False
# 60185                           False
#
#       Do you have a family history of mental illness  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
# ...                                              ...
# 60181                                   I don't know
# 60182                                   I don't know
# 60183                                   I don't know
# 60184                                   I don't know
# 60185                                   I don't know
#
#       Have you had a mental health disorder in the past  \
# 0                                                   Yes
# 1                                                   Yes
# 2                                                   Yes
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 60181                                               Yes
# 60182                                               Yes
# 60183                                               Yes
# 60184                                               Yes
# 60185                                               Yes
#
#       Do you currently have a mental health disorder  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
# ...                                              ...
# 60181                                            Yes
# 60182                                            Yes
# 60183                                            Yes
# 60184                                            Yes
# 60185                                            Yes
#
#       If yes, what conditions have you been diagnosed with  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60181  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60182  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60183  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60184  Obsessive-Compulsive Disorder|Eating Disorder ...
# 60185  Obsessive-Compulsive Disorder|Eating Disorder ...
#
#       If maybe, what conditions do you believe you have  ...   Age  \
# 0                                                   NaN  ...  39.0
# 1                                                   NaN  ...  39.0
# 2                                                   NaN  ...  39.0
# 3                                                   NaN  ...  39.0
# 4                                                   NaN  ...  39.0
# ...                                                 ...  ...   ...
# 60181                                               NaN  ...  25.0
# 60182                                               NaN  ...  25.0
# 60183                                               NaN  ...  25.0
# 60184                                               NaN  ...  25.0
# 60185                                               NaN  ...  25.0
#
#       What is your gender   Age group  What country do you live in  \
# 0                     Male      36-40               United Kingdom
# 1                     Male      36-40               United Kingdom
# 2                     Male      36-40               United Kingdom
# 3                     Male      36-40               United Kingdom
# 4                     Male      36-40               United Kingdom
# ...                    ...        ...                          ...
# 60181          Trans/Other      20-25                       Canada
# 60182          Trans/Other      20-25                       Canada
# 60183          Trans/Other      20-25                       Canada
# 60184          Trans/Other      20-25                       Canada
# 60185          Trans/Other      20-25                       Canada
#
#       What US state or territory do you live in What country do you work in  \
# 0                                           NaN              United Kingdom
# 1                                           NaN              United Kingdom
# 2                                           NaN              United Kingdom
# 3                                           NaN              United Kingdom
# 4                                           NaN              United Kingdom
# ...                                         ...                         ...
# 60181                                       NaN                      Canada
# 60182                                       NaN                      Canada
# 60183                                       NaN                      Canada
# 60184                                       NaN                      Canada
# 60185                                       NaN                      Canada
#
#       What US state or territory do you work in  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 60181                                       NaN
# 60182                                       NaN
# 60183                                       NaN
# 60184                                       NaN
# 60185                                       NaN
#
#       Which of the following best describes your work position  \
# 0                                     Back-end Developer
# 1                                     Back-end Developer
# 2                                     Back-end Developer
# 3                                     Back-end Developer
# 4                                     Back-end Developer
# ...                                                  ...
# 60181                                              Other
# 60182                                              Other
# 60183                                              Other
# 60184                                              Other
# 60185                                              Other
#
#       Do you work remotely  \
# 0                Sometimes
# 1                Sometimes
# 2                Sometimes
# 3                Sometimes
# 4                Sometimes
# ...                    ...
# 60181            Sometimes
# 60182            Sometimes
# 60183            Sometimes
# 60184            Sometimes
# 60185            Sometimes
#
#       Question about speaking openly about mental health vs physical health
# 0                                                     No
# 1                                                     No
# 2                                                     No
# 3                                                     No
# 4                                                     No
# ...                                                  ...
# 60181                                                 No
# 60182                                                 No
# 60183                                                 No
# 60184                                                 No
# 60185                                                 No
#
# [60186 rows x 23 columns]
